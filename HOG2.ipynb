# %%
pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in c:\users\admin\anaconda3\envs\vaisalee\lib\site-packages (0.23.1)
# Requirement already satisfied: numpy>=1.23 in c:\users\admin\anaconda3\envs\vaisalee\lib\site-packages (from scikit-image) (1.26.0)
# Requirement already satisfied: scipy>=1.9 in c:\users\admin\anaconda3\envs\vaisalee\lib\site-packages (from scikit-image) (1.11.3)
# Requirement already satisfied: networkx>=2.8 in c:\users\admin\anaconda3\envs\vaisalee\lib\site-packages (from scikit-image) (3.1)
# Requirement already satisfied: pillow>=9.1 in c:\users\admin\anaconda3\envs\vaisalee\lib\site-packages (from scikit-image) (10.0.1)
# Requirement already satisfied: imageio>=2.33 in c:\users\admin\anaconda3\envs\vaisalee\lib\site-packages (from scikit-image) (2.34.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\admin\anaconda3\envs\vaisalee\lib\site-packages (from scikit-image) (2024.2.12)
# Requirement already satisfied: packaging>=21 in c:\users\admin\anaconda3\envs\vaisalee\lib\site-packages (from scikit-image) (23.1)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\admin\anaconda3\envs\vaisalee\lib\site-packages (from scikit-image) (0.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # import libraries

# %%
from skimage.io import imread
from skimage.transform import resize
from skimage.feature import hog
import matplotlib.pyplot as plt

# %% [markdown]
# # reading the image

# %%
img=imread('C:/Users/admin/Downloads/butterfly.jpg')
plt.axis("off")
plt.imshow(img)
print(img.shape)
# Out:
# (120, 120, 3)

# %% [markdown]
# # resize the image

# %%
resized_img=resize(img,(128*10,64*10))
plt.axis("off")
plt.imshow(resized_img)
plt.show()
print(resized_img.shape)
# Out:
# (1280, 640, 3)

# %% [markdown]
# # CREATING HOG FEATURES

# %%
fd,hog_image=hog(img,orientations=10,pixels_per_cell=(2,2),
                cells_per_block=(4,4),visualize=True,channel_axis=2)
print(fd.shape)
print(hog_image.shape)
plt.axis("off")
plt.imshow(hog_image,cmap='gray')
plt.show()
# Out:
# (519840,)
# (120, 120)
